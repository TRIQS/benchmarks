# %% [markdown]
# # Dimer with Spin-Orbit Coupling
#
# Two-site dimer with spin-orbit coupling.

# %%
import sys
sys.path.append('../common')
from model import *
from analysis import load_all_results, compute_sigma, deviation_table, \
    plot_iw_comparison, plot_w_comparison, plot_static_obs_table, plot_chi_contour

# %%
data = load_all_results()
block_lst = list(data[next(iter(data))]['G'].indices) if data else []

# %% [markdown]
# ## 1. Single-Particle Green Function $G(i\omega_n)$

# %%
G_dict = {s: d['G'] for s, d in data.items() if 'G' in d}
if G_dict:
    plot_iw_comparison(G_dict, 'G', block_lst)
    deviation_table(G_dict, block_lst, label='G')
# Out:
#   G max-norm deviations:
#                 alps_cthyb    atomdiag       ctint     pomerol        pyed
#     alps_cthyb                3.45e-01    3.56e-01    3.45e-01    3.45e-01
#       atomdiag                            1.64e-02    6.08e-07    2.41e-14
#          ctint                                        1.64e-02    1.64e-02
#        pomerol                                                    6.08e-07
#           pyed

# %% [markdown]
# ## 2. Self-Energy $\Sigma(i\omega_n)$

# %%
Sigma_dict = compute_sigma(data, G0_iw)
if Sigma_dict:
    plot_iw_comparison(Sigma_dict, r'$\Sigma$', block_lst)
    deviation_table(Sigma_dict, block_lst, label='Sigma')
# Out:
#   Sigma max-norm deviations:
#                 alps_cthyb    atomdiag       ctint     pomerol        pyed
#     alps_cthyb                1.38e+02    1.38e+02    1.38e+02    1.38e+02
#       atomdiag                            2.13e-01    1.97e-04    3.89e-12
#          ctint                                        2.13e-01    2.13e-01
#        pomerol                                                    1.97e-04
#           pyed

# %% [markdown]
# ## 3. Static Observables

# %%
plot_static_obs_table(data, 'density')
plot_static_obs_table(data, 'nn_ab')
# Out:
#   density:
#     atomdiag              bl_0: 0.423719+0.000000j, bl_1: 0.398053+0.000000j, bl_2: 0.423719+0.000000j, bl_3: 0.398053+0.000000j
#     ctint                 bl_0: 0.421636, bl_1: 0.395356, bl_2: 0.421355, bl_3: 0.395075
#     pomerol               bl_0: 0.423719+0.000000j, bl_1: 0.398053+0.000000j, bl_2: 0.423719+0.000000j, bl_3: 0.398053+0.000000j
#     pyed                  bl_0: 0.423719-0.000000j, bl_1: 0.398053-0.000000j, bl_2: 0.423719+0.000000j, bl_3: 0.398053+0.000000j
#
#   nn_ab:
#     atomdiag              bl_0,bl_0: 0.423719+0.000000j, bl_0,bl_1: 0.106250+0.000000j, bl_0,bl_2: 0.167715+0.000000j, bl_0,bl_3: 0.121193+0.000000j, bl_1,bl_0: 0.106250+0.000000j, bl_1,bl_1: 0.398053+0.000000j, bl_1,bl_2: 0.121193+0.000000j, bl_1,bl_3: 0.146877+0.000000j, bl_2,bl_0: 0.167715+0.000000j, bl_2,bl_1: 0.121193+0.000000j, bl_2,bl_2: 0.423719+0.000000j, bl_2,bl_3: 0.106250+0.000000j, bl_3,bl_0: 0.121193+0.000000j, bl_3,bl_1: 0.146877+0.000000j, bl_3,bl_2: 0.106250+0.000000j, bl_3,bl_3: 0.398053+0.000000j
#     pomerol               bl_0,bl_0: 0.423719+0.000000j, bl_0,bl_1: 0.106250+0.000000j, bl_0,bl_2: 0.167715+0.000000j, bl_0,bl_3: 0.121193+0.000000j, bl_1,bl_0: 0.106250+0.000000j, bl_1,bl_1: 0.398053+0.000000j, bl_1,bl_2: 0.121193+0.000000j, bl_1,bl_3: 0.146877+0.000000j, bl_2,bl_0: 0.167715+0.000000j, bl_2,bl_1: 0.121193+0.000000j, bl_2,bl_2: 0.423719+0.000000j, bl_2,bl_3: 0.106250+0.000000j, bl_3,bl_0: 0.121193+0.000000j, bl_3,bl_1: 0.146877+0.000000j, bl_3,bl_2: 0.106250+0.000000j, bl_3,bl_3: 0.398053+0.000000j
#     pyed                  bl_0,bl_0: 0.423719-0.000000j, bl_0,bl_1: 0.106250-0.000000j, bl_0,bl_2: 0.167715+0.000000j, bl_0,bl_3: 0.121193+0.000000j, bl_1,bl_0: 0.106250-0.000000j, bl_1,bl_1: 0.398053-0.000000j, bl_1,bl_2: 0.121193+0.000000j, bl_1,bl_3: 0.146877-0.000000j, bl_2,bl_0: 0.167715+0.000000j, bl_2,bl_1: 0.121193+0.000000j, bl_2,bl_2: 0.423719+0.000000j, bl_2,bl_3: 0.106250-0.000000j, bl_3,bl_0: 0.121193+0.000000j, bl_3,bl_1: 0.146877-0.000000j, bl_3,bl_2: 0.106250-0.000000j, bl_3,bl_3: 0.398053+0.000000j

# %% [markdown]
# ## 4. Real-Frequency Spectral Function $A(\omega)$

# %%
G_w_dict = {s: d['G_w'] for s, d in data.items() if 'G_w' in d}
if G_w_dict:
    plot_w_comparison(G_w_dict, 'G_w', block_lst, spectral=True)
else:
    print("No solver has real-frequency data.")

# %% [markdown]
# ## 5. Three-Point Correlator $\chi_3$

# %%
for ch in ['d', 'm', 's', 't']:
    key = f'chi3_{ch}'
    chi3 = {s: d[key] for s, d in data.items() if key in d}
    if chi3:
        plot_chi_contour(chi3, ch)

# %% [markdown]
# ## 6. Two-Particle Green Function $\chi_4$ / $G_{2c}$

# %%
for ch in ['d', 'm', 's', 't']:
    key = f'chi4_{ch}'
    chi4 = {s: d[key] for s, d in data.items() if key in d}
    if chi4:
        plot_chi_contour(chi4, ch)
